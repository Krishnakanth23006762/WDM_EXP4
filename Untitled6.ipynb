# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("clustervisitor (1).csv")

# Define age groups
cluster = {
    "young": (df['Age'] <= 30),
    "middle": (df['Age'] > 30) & (df['Age'] <= 50),
    "old": (df['Age'] > 50)
}

# Initialize count CLEAN
count = []

for group, condition in cluster.items():
    visitors = df[condition]
    visitor_count = len(visitors)
    count.append(visitor_count)

    print(f"Visitors in {group} age group:")
    print(visitors)
    print(f"Total visitors: {visitor_count}")
    print("-" * 30)

# Plot
labels = list(cluster.keys())

plt.figure(figsize=(8, 6))
plt.bar(labels, count, color='skyblue')
plt.xlabel('Age Groups')
plt.ylabel('Number of Visitors')
plt.title('Visitor Distribution Across Age Groups')
plt.show()
# Out:
# Visitors in young age group:
#     User_ID  Age  Gender      Location  Income
# 0         1   25  Female      New York  119302
# 2         3   22    Male       Chicago   82290
# 4         5   30    Male         Miami   70361
# 6         7   28  Female        Boston   32439
# 11       12   27    Male        Austin   92812
# 14       15   29  Female  Philadelphia   77364
# 17       18   26    Male   Minneapolis   75579
# 27       28   24  Female    Sacramento   71729
# Total visitors: 8
# ------------------------------
# Visitors in middle age group:
#     User_ID  Age  Gender         Location  Income
# 1         2   40    Male      Los Angeles   45324
# 5         6   45  Female    San Francisco  115650
# 7         8   50    Male          Seattle   92538
# 8         9   35    Male           Dallas   57960
# 9        10   48  Female          Atlanta   53237
# 10       11   33  Female  Washington D.C.  100282
# 12       13   38    Male           Denver   90069
# 13       14   42  Female          Phoenix   41423
# 15       16   36    Male         Portland  108470
# 18       19   31  Female        Charlotte  119489
# 19       20   47    Male        San Diego   51503
# 20       21   34    Male         San Jose   96323
# 21       22   39  Female     Indianapolis  112845
# 22       23   43    Male        Las Vegas   47573
# 23       24   32  Female          Orlando  101845
# 24       25   37    Male            Tampa  109704
# 25       26   44  Female        St. Louis  104933
# 26       27   49    Male      Kansas City   52351
# 28       29   41    Male        Cleveland   78567
# 29       30   46  Female       Pittsburgh   50725
# Total visitors: 20
# ------------------------------
# Visitors in old age group:
#     User_ID  Age  Gender Location  Income
# 3         4   55  Female  Houston   77799
# 16       17   51  Female  Detroit   70670
# Total visitors: 2
# ------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Load data
df = pd.read_csv("clustervisitor (1).csv")

# Select features
X = df[['Age', 'Income']]

# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply KMeans
kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# Display dataframe
print(df, "\n")

# Plot clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['Age'], df['Income'], c=df['Cluster'], cmap='viridis')
plt.xlabel('Age')
plt.ylabel('Income (in thousands)')
plt.title('K-Means Clustering of Visitors')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#     User_ID  Age  Gender         Location  Income  Cluster
# 0         1   25  Female         New York  119302        1
# 1         2   40    Male      Los Angeles   45324        0
# 2         3   22    Male          Chicago   82290        2
# 3         4   55  Female          Houston   77799        3
# 4         5   30    Male            Miami   70361        2
# 5         6   45  Female    San Francisco  115650        3
# 6         7   28  Female           Boston   32439        2
# 7         8   50    Male          Seattle   92538        3
# 8         9   35    Male           Dallas   57960        2
# 9        10   48  Female          Atlanta   53237        0
# 10       11   33  Female  Washington D.C.  100282        1
# 11       12   27    Male           Austin   92812        2
# 12       13   38    Male           Denver   90069        1
# 13       14   42  Female          Phoenix   41423        0
# 14       15   29  Female     Philadelphia   77364        2
# 15       16   36    Male         Portland  108470        1
# 16       17   51  Female          Detroit   70670        3
# 17       18   26    Male      Minneapolis   75579        2
# 18       19   31  Female        Charlotte  119489        1
# 19       20   47    Male        San Diego   51503        0
# 20       21   34    Male         San Jose   96323        1
# 21       22   39  Female     Indianapolis  112845        1
# 22       23   43    Male        Las Vegas   47573        0
# 23       24   32  Female          Orlando  101845        1
# 24       25   37    Male            Tampa  109704        1
# 25       26   44  Female        St. Louis  104933        3
# 26       27   49    Male      Kansas City   52351        0
# 27       28   24  Female       Sacramento   71729        2
# 28       29   41    Male        Cleveland   78567        3
# 29       30   46  Female       Pittsburgh   50725        0
